# %%
def suma(a,b):
  return a+b

def resta(a,b):
  return a-b

def multiplica(a,b):
  return a*b

def div(a,b):
  try:
    return a/b
    except ZeroDivisionError:
      print("no se puede dividir un numero entre cero")
      return "operacion erronea"

ope1=int(input("introduce el operando 1"))
ope2=int(input("introduce el operando 2"))
operacion=input("introduce la operacion a realizar +, -, * o / \n")
