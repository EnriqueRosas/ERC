# %%
dato = "from enrlsndkikeperes98@gmail.com sat jan 053743kj"
arrobapos = dato.find("@")
espos = dato.find(" ",arrobapos)
direccion = dato[arrobapos+1:espos]
print(direccion)
# Out:
# gmail.com
