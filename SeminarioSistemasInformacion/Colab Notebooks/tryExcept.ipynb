# %%
while True:
  linea = input(">")
  try:
    if linea[0] == "#":
      continue
  except IndexError:
    print("no se capturi ninguna cadena")
  if linea == "fin":
    break
  print(linea)
print("terminado")
# Out:
# >fin
# terminado
