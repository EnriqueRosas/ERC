# %%
# Ingresar la matriz desde el usuario
matriz_original = []
for i in range(3):
    fila = []
    for j in range(3):
        elemento = int(input(f"Ingrese el elemento en la posición ({i+1},{j+1}): "))
        fila.append(elemento)
    matriz_original.append(fila)

# Mostrar la matriz original
print("\nMatriz original:")
for fila in matriz_original:
    print(fila)

# Calcular y mostrar la traspuesta de la matriz
matriz_traspuesta = []
for j in range(3):
    fila_traspuesta = [matriz_original[i][j] for i in range(3)]
    matriz_traspuesta.append(fila_traspuesta)

print("\nMatriz traspuesta:")
for fila in matriz_traspuesta:
    print(fila)# Ingresar la matriz desde el usuario
matriz_original = []
for i in range(3):
    fila = []
    for j in range(3):
        elemento = int(input(f"Ingrese el elemento en la posición ({i+1},{j+1}): "))
        fila.append(elemento)
    matriz_original.append(fila)

# Mostrar la matriz original
print("\nMatriz original:")
for fila in matriz_original:
    print(fila)

# Calcular y mostrar la traspuesta de la matriz
matriz_traspuesta = []
for j in range(3):
    fila_traspuesta = [matriz_original[i][j] for i in range(3)]
    matriz_traspuesta.append(fila_traspuesta)

print("\nMatriz traspuesta:")
for fila in matriz_traspuesta:
    print(fila)
# Out:
# Ingrese el elemento en la posición (1,1): 1
# Ingrese el elemento en la posición (1,2): 2
# Ingrese el elemento en la posición (1,3): 3
# Ingrese el elemento en la posición (2,1): 1
# Ingrese el elemento en la posición (2,2): 2
# Ingrese el elemento en la posición (2,3): 3
# Ingrese el elemento en la posición (3,1): 1
# Ingrese el elemento en la posición (3,2): 2
# Ingrese el elemento en la posición (3,3): 3
#
# Matriz original:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
#
# Matriz traspuesta:
# [1, 1, 1]
# [2, 2, 2]
# [3, 3, 3]
# Ingrese el elemento en la posición (1,1): 1
# Ingrese el elemento en la posición (1,2): 2
# Ingrese el elemento en la posición (1,3): 3
# Ingrese el elemento en la posición (2,1): 1
# Ingrese el elemento en la posición (2,2): 2
# Ingrese el elemento en la posición (2,3): 3
# Ingrese el elemento en la posición (3,1): 1
# Ingrese el elemento en la posición (3,2): 2
# Ingrese el elemento en la posición (3,3): 3
#
# Matriz original:
# [1, 2, 3]
# [1, 2, 3]
# ...
