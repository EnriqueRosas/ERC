# %%
s = "Monty Python"
print(s[0:5])
print(s[6:12])
print(s[6])

fruta = "banana"
fruta[3:]
fruta[:3]

palabra == "banana"
# Out:
# Monty
# Python
# P
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5d6344630f6b> in <cell line: 10>()
#       8 fruta[:3]
#       9
# ---> 10 palabra == "banana"
#      11
#
# NameError: name 'palabra' is not defined
